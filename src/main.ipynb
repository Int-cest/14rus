# %%
from parcer import *
from config import PATH_DATA

# %%
from pipeline import Pipeline
from report import save_csv, save_json, save_md

if __name__ == "__main__":
    pipeline = Pipeline()

    results = pipeline.run(PATH_DATA)

    save_csv(results)
    save_json(results)
    save_md(results)
