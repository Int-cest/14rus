# %%
from parcer import *
from config import PATH_DATA
import csv

# %%
factory = ParserFactory()
print(f"--- Начинаю сканирование директории: {PATH_DATA} ---")
results = factory.scan_directory(PATH_DATA)
print(f"--- Обработка завершена. Файлов: {len(results)} ---")

output_file_csv = "result.csv"

try:
    with open(output_file_csv, "w", encoding="utf-8", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=["path", "content"], extrasaction='ignore')
        
        writer.writeheader()
        for res in results:
            if res.get("content"):
                res["content"] = " ".join(res["content"].split())
            writer.writerow(res)
            
    print(f"Результаты парсинга успешно сохранены в {output_file_csv}")

except Exception as e:
    print(f"Ошибка при сохранении CSV: {e}")
# Out:
# 2026-04-18 20:56:35,258 | INFO | parcer | [ParserFactory] Инициализирован. Поддерживаемых расширений: 19
# 2026-04-18 20:56:35,260 | INFO | parcer | [ParserFactory] Старт сканирования директории: ..\datasets\test
# 2026-04-18 20:56:35,264 | INFO | parcer | [ParserFactory] Создание парсера для типа: image
# 2026-04-18 20:56:35,265 | INFO | parcer | [ParserFactory] ..\datasets\test\0.gif -> image
# 2026-04-18 20:56:35,266 | INFO | parcer | [Images] Старт OCR ..\datasets\test\0.gif
# 2026-04-18 20:56:35,267 | INFO | parcer | Загрузка EasyOCR модели...
# 2026-04-18 20:56:35,269 | WARNING | easyocr.easyocr | Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# --- Начинаю сканирование директории: ..\datasets\test ---
# c:\Users\User\projects\int-cest\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2026-04-18 20:56:42,491 | INFO | parcer | [Images] Завершено ..\datasets\test\0.gif | chars=192 | 7.22s
# 2026-04-18 20:56:42,501 | INFO | parcer | [ParserFactory] ..\datasets\test\0_a6315_aaf0ed1a_XL.jpg -> image
# 2026-04-18 20:56:42,502 | INFO | parcer | [Images] Старт OCR ..\datasets\test\0_a6315_aaf0ed1a_XL.jpg
# c:\Users\User\projects\int-cest\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2026-04-18 20:56:44,834 | INFO | parcer | [Images] Завершено ..\datasets\test\0_a6315_aaf0ed1a_XL.jpg | chars=51 | 2.33s
# 2026-04-18 20:56:44,836 | INFO | parcer | [ParserFactory] ..\datasets\test\50308888-8889.tif -> image
# 2026-04-18 20:56:44,837 | INFO | parcer | [Images] Старт OCR ..\datasets\test\50308888-8889.tif
# c:\Users\User\projects\int-cest\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2026-04-18 20:57:00,223 | INFO | parcer | [Images] Завершено ..\datasets\test\50308888-8889.tif | chars=1760 | 15.39s
# 2026-04-18 20:57:00,234 | INFO | parcer | [ParserFactory] Создание парсера для типа: document
# 2026-04-18 20:57:00,235 | INFO | parcer | [ParserFactory] ..\datasets\test\agreement_reg_extra.pdf -> document
# 2026-04-18 20:57:00,235 | INFO | parcer | [Documents] Старт парсинга ..\datasets\test\agreement_reg_extra.pdf
# 2026-04-18 20:57:00,306 | INFO | parcer | [Documents] Завершено ..\datasets\test\agreement_reg_extra.pdf | chars=18682 | 0.07s
# 2026-04-18 20:57:00,308 | INFO | parcer | [ParserFactory] Создание парсера для типа: structured
# 2026-04-18 20:57:00,309 | INFO | parcer | [ParserFactory] ..\datasets\test\client.parquet -> structured
# 2026-04-18 20:57:00,311 | INFO | parcer | [StructureData] Старт парсинга ..\datasets\test\client.parquet
# 2026-04-18 20:57:00,313 | WARNING | parcer | [StructureData] Ошибка парсинга ..\datasets\test\client.parquet: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.
# 2026-04-18 20:57:00,314 | INFO | parcer | [StructureData] Завершено ..\datasets\test\client.parquet | chars=456 | 0.00s
# 2026-04-18 20:57:00,315 | INFO | parcer | [ParserFactory] Создание парсера для типа: video
# 2026-04-18 20:57:00,317 | INFO | parcer | [ParserFactory] ..\datasets\test\CS10.mp4 -> video
# 2026-04-18 20:57:00,318 | INFO | parcer | [Videos] Старт OCR по кадрам ..\datasets\test\CS10.mp4
# 2026-04-18 20:58:10,086 | INFO | parcer | [Videos] Завершено ..\datasets\test\CS10.mp4 | sampled_frames=6 | chars=1322 | 69.77s
# 2026-04-18 20:58:10,115 | INFO | parcer | [ParserFactory] Создание парсера для типа: web
# 2026-04-18 20:58:10,116 | INFO | parcer | [ParserFactory] ..\datasets\test\page_38.html -> web
# 2026-04-18 20:58:10,117 | INFO | parcer | [WebContent] Парсер не реализован для ..\datasets\test\page_38.html
# 2026-04-18 20:58:10,119 | INFO | parcer | [ParserFactory] ..\datasets\test\plan.json -> structured
# 2026-04-18 20:58:10,120 | INFO | parcer | [StructureData] Старт парсинга ..\datasets\test\plan.json
# 2026-04-18 20:58:10,138 | INFO | parcer | [StructureData] Завершено ..\datasets\test\plan.json | chars=2621 | 0.02s
# 2026-04-18 20:58:10,140 | INFO | parcer | [ParserFactory] ..\datasets\test\psxattrs.csv -> structured
# 2026-04-18 20:58:10,141 | INFO | parcer | [StructureData] Старт парсинга ..\datasets\test\psxattrs.csv
# 2026-04-18 20:58:10,156 | INFO | parcer | [StructureData] Завершено ..\datasets\test\psxattrs.csv | chars=500 | 0.01s
# 2026-04-18 20:58:10,157 | INFO | parcer | [ParserFactory] ..\datasets\test\sample.md -> document
# 2026-04-18 20:58:10,158 | INFO | parcer | [Documents] Старт парсинга ..\datasets\test\sample.md
# 2026-04-18 20:58:10,176 | INFO | parcer | [Documents] Завершено ..\datasets\test\sample.md | chars=6244 | 0.02s
# 2026-04-18 20:58:10,178 | INFO | parcer | [ParserFactory] ..\datasets\test\zayavka_kompensaciya_interneta.txt -> document
# 2026-04-18 20:58:10,179 | INFO | parcer | [Documents] Старт парсинга ..\datasets\test\zayavka_kompensaciya_interneta.txt
# 2026-04-18 20:58:10,193 | INFO | parcer | [Documents] Завершено ..\datasets\test\zayavka_kompensaciya_interneta.txt | chars=849 | 0.01s
# 2026-04-18 20:58:10,195 | INFO | parcer | [ParserFactory] ..\datasets\test\_%D1%83%D1%87%D0%B0%D1%81%D1%82%D0%B8%D0%B5%20%D0%B2%20%D0%9F%D0%98%D0%A0%20%D0%B3%D0%BE%D1%81%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9.doc -> document
# 2026-04-18 20:58:10,196 | INFO | parcer | [Documents] Старт парсинга ..\datasets\test\_%D1%83%D1%87%D0%B0%D1%81%D1%82%D0%B8%D0%B5%20%D0%B2%20%D0%9F%D0%98%D0%A0%20%D0%B3%D0%BE%D1%81%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9.doc
# 2026-04-18 20:58:12,979 | INFO | parcer | [Documents] Чтение через Word COM: c:\Users\User\projects\int-cest\src\..\datasets\test\_%D1%83%D1%87%D0%B0%D1%81%D1%82%D0%B8%D0%B5%20%D0%B2%20%D0%9F%D0%98%D0%A0%20%D0%B3%D0%BE%D1%81%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9.doc
# 2026-04-18 20:58:16,744 | INFO | parcer | [Documents] Завершено ..\datasets\test\_%D1%83%D1%87%D0%B0%D1%81%D1%82%D0%B8%D0%B5%20%D0%B2%20%D0%9F%D0%98%D0%A0%20%D0%B3%D0%BE%D1%81%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B9.doc | chars=28 | 6.55s
# 2026-04-18 20:58:16,746 | INFO | parcer | [ParserFactory] ..\datasets\test\_Universal Application Form 2018.doc -> document
# 2026-04-18 20:58:16,748 | INFO | parcer | [Documents] Старт парсинга ..\datasets\test\_Universal Application Form 2018.doc
# 2026-04-18 20:58:17,807 | INFO | parcer | [Documents] Чтение через Word COM: c:\Users\User\projects\int-cest\src\..\datasets\test\_Universal Application Form 2018.doc
# 2026-04-18 20:58:23,115 | INFO | parcer | [Documents] Завершено ..\datasets\test\_Universal Application Form 2018.doc | chars=2114 | 6.37s
# 2026-04-18 20:58:23,117 | INFO | parcer | [ParserFactory] Сканирование завершено: total_files=13, parsed_files=13
# --- Обработка завершена. Файлов: 13 ---
# Результаты парсинга успешно сохранены в result.csv
